# %%
import pandas as pd
import numpy as np
from tabulate import tabulate

df = pd.read_csv('Census_Enrichment.csv')  #Pretty simple, just reads and prints out the enrichment file obtained from the census

df = df.head()

print(df)
# Out:
#       County Name State  Estimate Total population  \
# 0   United States   NaN                  326569308
# 1         Alabama   NaN                    4893186
# 2  Autauga County    AL                      55639
# 3  Baldwin County    AL                     218289
# 4  Barbour County    AL                      25026
#
#    Estimate Total population Under 5 years  \
# 0                                 19650192
# 1                                   293932
# 2                                     3235
# 3                                    11960
# 4                                     1332
#
#    Estimate Total population 5 to 9 years  \
# 0                                19979039
# 1                                  294776
# 2                                    3725
# 3                                   11559
# 4                                    1550
#
#    Estimate Total population 10 to 14 years  \
# 0                                  21107910
# ...

# %%
#Each student member creates notebooks to read the Enrichment data and displays them on a notebook.

# %%
df = pd.read_csv('Census_Enrichment.csv')
covid = pd.read_csv('super_covid_data.csv') 

#df = df.head()
#covid = covid.head()

merged = pd.merge(df, covid, on=['County Name', 'State'], how='left')  #This merges the two files on the State column

merged.head()
print(merged)


merged.to_csv('covidandreducedcencus.csv')  #This converts the merged dataframe into a new csv
# Out:
#             County Name State  Estimate Total population  \
# 0         United States   NaN                  326569308
# 1               Alabama   NaN                    4893186
# 2        Autauga County    AL                      55639
# 3        Baldwin County    AL                     218289
# 4        Barbour County    AL                      25026
# ...                 ...   ...                        ...
# 3190  Sweetwater County    WY                      43352
# 3191       Teton County    WY                      23356
# 3192       Uinta County    WY                      20374
# 3193    Washakie County    WY                       7933
# 3194      Weston County    WY                       6942
#
#       Estimate Total population Under 5 years  \
# 0                                    19650192
# 1                                      293932
# 2                                        3235
# 3                                       11960
# ...

# %%
#Each student member performs initial merges with the COVID-19 data using the variables in the Enrichment data.
